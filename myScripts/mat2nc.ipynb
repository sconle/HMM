# %%
# Storage management
import h5py   # Manages .mat files in Python
from loader import load_oneIC  # Stores temporarily useful data from our .mat data file in a dictionary
import xarray as xr   # Manages .nc (netCDF) files in Python.
                      # The states' informations are stored in a .nc file for each subject.

# Scientific computing
import numpy as np

# Else
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
directory = "E:/timot/Documents/1 - Centrale Marseille/_Stage S8/NIC_250819"
file = "FCK_LOCKED_IC_JYOTIKA_250819.mat"

path = f"{directory}/{file}"

mat_file = h5py.File(path, "r")
cells_refs = mat_file['FCK_LOCKED_IC_JYOTIKA']

n_IC = 4
n_subj = 23

# %%
data_dir = "E:/timot/Documents/1 - Centrale Marseille/0.6 - Semestre S9/2_Projet/HMM/data/"

# %%
for IC in range(1,5):
    for subj in range(1, 24):
        try:
            data, n_trials = load_oneIC(mat_file, cells_refs, subj, IC)
            ds = xr.Dataset(
                {
                    "timecourse": (("trials","time"), data['raw_timecourse_256Hz']),
                    "trialinfo": (("trials","info"), data['trialinfo']),
                },
                {
                    "time":data["time_axis"],
                }
            )
            ds.to_netcdf(data_dir + f"su{subj}IC{IC}_rawdata.nc")
        except:
            print(IC, subj)
# Out:
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# The independent component IC1 of the subject 20 is not in the .mat file.
# 1 20
# Loading the raw timecourse
# The independent component IC1 of the subject 21 is not in the .mat file.
# 1 21
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# Loading the raw timecourse
# ...
